# %%
import pandas as pd
data1231 = pd.read_csv("/home/shared/alpha_py_trade_dashboard/public/data/parallel_result_20251231.tsv",sep='\t')
print(data1231.columns)
# Out:
# Index(['CMNT_DATE', 'TITLE', 'CONTENT', 'drive_category', 'target_type',
#        'reason', 'identified_stock_names', 'identified_stock_codes',
#        'data_type', 'TEAM_CNAME', 'INST_CNAME', 'confidence', 'need_analysis',
#        'reasoning_content', 'parsed_json', 'basemap', 'enhanced_map',
#        'score_fundamental', 'score_short', 'score_medium', 'score_long',
#        'final_score', 'final_score_penalized', 'penalty_total', 'return',
#        'return_valid_codes', 'industry'],
#       dtype='object')

# %%
import pandas as pd
data0123 = pd.read_csv("/home/shared/alpha_py_trade_dashboard/public/data/parallel_result_20260123.tsv",sep='\t')
print(data0123.columns)
# Out:
# Index(['CMNT_DATE', 'TITLE', 'CONTENT', 'drive_category', 'target_type',
#        'reason', 'identified_stock_names', 'identified_stock_codes',
#        'data_type', 'CREATE_TIME', 'TEAM_CNAME', 'INST_CNAME', 'confidence',
#        'need_analysis', 'reasoning_content', 'parsed_json', 'basemap',
#        'enhanced_map', 'score_fundamental', 'score_short', 'score_medium',
#        'score_long', 'final_score', 'final_score_penalized', 'penalty_total',
#        'sentiment_score', 'investor_comments', 'return', 'return_valid_codes',
#        'industry'],
#       dtype='object')

# %%
data0123['CMNT_DATE'].describe()
# Out:
# count                     101
# unique                     17
# top       2026-01-22 00:00:00
# freq                       80
# Name: CMNT_DATE, dtype: object
